# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Александр, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Алексей, привет!*
#
# *Рад знакомству!*
# </div>

# %% [markdown]
# # Проект "Обучение с учителем: качество модели"

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# #### Общее описание:
# - Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты.
# - Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться.
# - Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории.
# - Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# - Поставлена задача разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# #### Описание задачи:

# %% [markdown]
# - Нужно промаркировать уровень финансовой активности постоянных покупателей.
#     - В компании принято 2 уровня активности:
#         - «снизилась», если клиент стал покупать меньше товаров
#         - «прежний уровень»
# - Нужно собрать данные по клиентам по следующим 4 группам признаков:
#     - описывают коммуникацию сотрудников компании с клиентом.
#     - описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#     - описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#     - описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
# - Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# - В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# - Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения

# %% [markdown]
# #### Описание данных
# 1. Таблица `market_file.csv` содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# 2. Таблица `market_money.csv` с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - `Выручка` — сумма выручки за период.
#
# 3. Таблица `market_time.csv` с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксировано общее время.
# - `минут` — значение времени, проведённого на сайте, в минутах.
#
# 4. Таблица `money.csv` с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Прибыль` — значение прибыли.

# %% [markdown]
# #### План проекта:
# - Шаг 1. Загрузка данных
# - Шаг 2. Предобработка данных
# - Шаг 3. Исследовательский анализ данных
# - Шаг 4. Объединение таблиц
# - Шаг 5. Корреляционный анализ
# - Шаг 6. Использование пайплайнов
# - Шаг 7. Анализ важности признаков
# - Шаг 8. Сегментация покупателей
# - Шаг 9. Общий вывод

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# #### Установим недостающие пакеты

# %%
import warnings
warnings.filterwarnings("ignore")
import sys
print(sys.prefix)

# !pip install phik -q
# !pip install shap -q
# !pip install --upgrade scikit-learn -q
# !pip install --upgrade pandas==1.5.0 -q
# Out:
# /opt/conda

# %% [markdown]
# #### Установим библиотеки

# %%
# Системные операции
import os 
# Работа с данными в табличном виде
import pandas as pd 
# Базовые математические операции
import numpy as np 
# Визуализация
import matplotlib.pyplot as plt 
import seaborn as sns

# Корреляционный анализ
import phik 
from phik import phik_matrix

# Заполнение пропусков
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder, OrdinalEncoder, RobustScaler, StandardScaler # Предобработка данных
# Объединение преобразований признаков
from sklearn.compose import ColumnTransformer 
# Пайплайны для объединения шагов предобработки и обучения
from sklearn.pipeline import Pipeline 


# Разбиение данных и подбор гиперпараметров
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV 
# Метрики качества
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, roc_auc_score 
# Анализ важности признаков
from sklearn.inspection import permutation_importance 
import shap

# Модели машинного обучения
from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.dummy import DummyClassifier

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Ты импортируешь библиотеки и модули, которые не используешь в проекте - так делать не стоит, так как ты забиваешь окружение лишними  инструментами.
#
# В блоке импорта стоит оставить только то, что реально используется в проекте.
# </div>

# %% [markdown]
# #### Загрузим файлы

# %%
try:
    customer_web_beh = pd.read_csv('/Users/erofeev-as/Desktop/Практикум/Датасэты/market_file.csv')
    customer_web_time = pd.read_csv('/Users/erofeev-as/Desktop/Практикум/Датасэты/market_time.csv')
    customer_value = pd.read_csv('/Users/erofeev-as/Desktop/Практикум/Датасэты/market_money.csv')
    customer_profit = pd.read_csv('/Users/erofeev-as/Desktop/Практикум/Датасэты/money.csv', sep = ';', decimal = ',')
except:
    customer_web_beh = pd.read_csv('https://code.s3.yandex.net/datasets/market_file.csv')
    customer_web_time = pd.read_csv('https://code.s3.yandex.net/datasets/market_time.csv')   
    customer_value = pd.read_csv('https://code.s3.yandex.net/datasets/market_money.csv')
    customer_profit = pd.read_csv('https://code.s3.yandex.net/datasets/money.csv', sep = ';', decimal = ',')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Данные загрузили - отлично!
#
# Здорово, что ты используешь конструкцию ``try-except`` для путей файлов. Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.

# %%
# Посмотрим на данные по поведению покупателей на сайте
customer_web_beh.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
# Посмотрим на данные по продолжительности пребывания покупателей на сайте
customer_web_time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
# Посмотрим на данные по продолжительности выручке покупателей
customer_value.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
# Посмотрим на данные по продолжительности прибыле от покупателей
customer_profit.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Предобрабработаем данные по поведению покупателей на сайте

# %%
# приведем к змеиному регистру
customer_web_beh.columns = map(str.lower, customer_web_beh.columns)
customer_web_beh.columns = customer_web_beh.columns.str.replace(' ', '_')

# %%
# выведем на экран
customer_web_beh.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# Видны опечатки, вместо стандарт, написано стандартт, посмотрим есть ли еще такие ошибки таки

# %%
def get_unique_values(df, columns_to_check=None):
    """
    Выводит перечень уникальных значений в указанных столбцах DataFrame.

    Args:
        df: pandas DataFrame.
        columns_to_check: Список названий столбцов для проверки. 
                         Если None, то проверяются все столбцы.
    """

    if columns_to_check is None:
        columns_to_check = df.columns

    for column in columns_to_check:
        unique_values = df[column].unique()
        print(f"Уникальные значения в столбце '{column}': {unique_values}")

# Для конкретных столбцов:
get_unique_values(customer_web_beh, columns_to_check=['покупательская_активность','тип_сервиса', 'разрешить_сообщать','популярная_категория','популярная_категория'])
# Out:
# Уникальные значения в столбце 'покупательская_активность': ['Снизилась' 'Прежний уровень']
# Уникальные значения в столбце 'тип_сервиса': ['премиум' 'стандартт' 'стандарт']
# Уникальные значения в столбце 'разрешить_сообщать': ['да' 'нет']
# Уникальные значения в столбце 'популярная_категория': ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
# Уникальные значения в столбце 'популярная_категория': ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %% [markdown]
# Видим, что это единственная опечатка, исправим это.

# %%
# Исправление данных
customer_web_beh['тип_сервиса'] = customer_web_beh['тип_сервиса'].replace(['стандартт'],'стандарт')

# %%
# Проверим
display(customer_web_beh['тип_сервиса'].unique())
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %%
# Посмотрим на типы данных
print(customer_web_beh.dtypes)
# Out:
# id                                       int64
# покупательская_активность               object
# тип_сервиса                             object
# разрешить_сообщать                      object
# маркет_актив_6_мес                     float64
# маркет_актив_тек_мес                     int64
# длительность                             int64
# акционные_покупки                      float64
# популярная_категория                    object
# средний_просмотр_категорий_за_визит      int64
# неоплаченные_продукты_штук_квартал       int64
# ошибка_сервиса                           int64
# страниц_за_визит                         int64
# dtype: object

# %% [markdown]
# Проанализируем типы и данных и определим необходимые изменения:
# - `id`: Тип данных int (целое число) корректен.
#
# - `покупательская_активность`: категориальная переменная. Тип данных object (строка) приемлем.
#
# - `тип_сервиса`: категориальная переменная. Тип данных object приемлем.
#
# - `разрешить_сообщать`: Тип данных object приемлем.
#
# - `маркет_актив_6_мес`: вещественное число (с плавающей точкой). Тип данных float корректен.
#
# - `маркет_актив_тек_мес`: тип данных должен быть int.
# - `длительность`: целое число, тип данных int корректен.
#
# - `акционные_покупки`: вещественное число (доля акционных покупок?), тип данных float корректен.
#
# - `популярная_категория`: категориальная переменная, тип данных object приемлем, но рекомендуется преобразовать в category.
#
# - `средний_просмотр_категорий_за_визит`: целое число, тип данных int корректен.
#
# - `неоплаченные_продукты_штук_квартал`: целое число, тип данных int корректен.
#
# - `ошибка_сервиса`: количество ошибок, тип данных int корректен.
#
# - `страниц_за_визит`: целое число. Тип данных int корректен.

# %% [markdown]
# #### Предобрабработаем данные по продолжительности нахождения покупателей на сайте

# %%
# приведем к змеиному регистру
customer_web_time.columns = map(str.lower, customer_web_time.columns)

# %%
# посмотрим на данные 
customer_web_time.head()
# Out:
#        id            период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %% [markdown]
# Есть опечатки, проверим

# %%
# Проверим
display(customer_web_time['период'].unique())
# Out:
# array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)

# %%
# Исправим опечатки
customer_web_time['период'] = customer_web_time['период'].replace(['предыдцщий_месяц'],'предыдущий_месяц')

# %%
# Проверим исправления
display(customer_web_time['период'].unique())
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %%
# Посмотрим на типы данных
print(customer_web_time.dtypes)
# Out:
# id         int64
# период    object
# минут      int64
# dtype: object

# %% [markdown]
# Проанализируем типы данных и определим необходимые изменения:
# - `id`: Тип данных int (целое число) корректен.
#
# - `период`: Тип данных object категориальная переменная, корректен
#
# - `минут`: целое число, тип данных int корректен.

# %%
# Проверим дубликаты
print('Явных дубликатов:', customer_web_time.duplicated().sum(), '\n')
customer_web_time.info()
# Out:
# Явных дубликатов: 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# #### Предобрабработаем данные по выручке покупателей

# %%
# Посмотрим на данные 
customer_value.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
# Приведем к змеиному регистру
customer_value.columns = map(str.lower, customer_value.columns)

# %%
# Посмотрим на значения в столбце
display(customer_value['период'].unique())
# Out:
# array(['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#       dtype=object)

# %%
# Проверим дубликаты
print('Явных дубликатов:', customer_value.duplicated().sum(), '\n')
customer_value.info()
# Out:
# Явных дубликатов: 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Проанализируем типы данных и определим необходимые изменения:
# - `id`: Тип данных int (целое число) корректен.
#
# - `период`: Тип данных object категориальная переменная, корректен.
#
# - `минут`: корректный тип`float64`

# %% [markdown]
# #### Предобрабработаем данные по прибыли по клиентам

# %%
# Посмотрим на данные 
customer_profit.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
# Приведем к змеиному регистру
customer_profit.columns = map(str.lower, customer_profit.columns)

# %%
# Проверим дубликаты
print('Явных дубликатов:', customer_profit.duplicated().sum(), '\n')
customer_profit.info()
# Out:
# Явных дубликатов: 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# Проанализируем типы данных и определим необходимые изменения:
# - `id`: Тип данных int (целое число) корректен.
#
# - `выручка`: корректный тип`float64`

# %% [markdown]
# #### Приведем название столбцов к одной логике, с учетом, что дальше будем объединять датафреймы

# %%
# выведем названия всех столбцов
print(customer_web_beh.columns)
print(customer_web_time.columns)
print(customer_value.columns)
print(customer_profit.columns)
# Out:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')
# Index(['id', 'период', 'минут'], dtype='object')
# Index(['id', 'период', 'выручка'], dtype='object')
# Index(['id', 'прибыль'], dtype='object')

# %%
# Переименуем все столбцы в cow в соответсвующие ferma и преведем во всех датафреймах к змеиному регистру
possible_columns = {
    'id': 'customer_id',
    'покупательская_активность' : 'customer_activity',
    'тип_сервиса' : 'service_type',
    'разрешить_сообщать' : 'adv_permision',
    'маркет_актив_6_мес' : '6_m_adv_activity',
    'маркет_актив_тек_мес' : 'act_m_adv_activity',
    'длительность': 'life_time_days',
    'акционные_покупки' : '%_promotion_purchases',
    'популярная_категория' : 'favorite_category',
    'средний_просмотр_категорий_за_визит' : 'avg_category_view_by_visit_last_m',
    'неоплаченные_продукты_штук_квартал' : 'unpaid_purch_qtr',
    'ошибка_сервиса' : 'site_crash_numb',
    'страниц_за_визит' : 'pages_per_visits_3_m',
    'период' : 'period_name',
    'минут' : 'time_spent_on_site_min',
    'прибыль' : 'customer_profit',
    'выручка' : 'revenue',
    
}

customer_web_beh.rename(columns=possible_columns, inplace=True)
customer_web_time.rename(columns=possible_columns, inplace=True)
customer_value.rename(columns=possible_columns, inplace=True)
customer_profit.rename(columns=possible_columns, inplace=True)

# %%
customer_web_beh.head()
# Out:
#    customer_id customer_activity service_type adv_permision  6_m_adv_activity  \
# 0       215348         Снизилась      премиум            да               3.4
# 1       215349         Снизилась      премиум            да               4.4
# 2       215350         Снизилась     стандарт           нет               4.9
# 3       215351         Снизилась     стандарт            да               3.2
# 4       215352         Снизилась     стандарт           нет               5.1
#
#    act_m_adv_activity  life_time_days  %_promotion_purchases  \
# 0                   5             121                   0.00
# 1                   4             819                   0.75
# 2                   3             539                   0.14
# 3                   5             896                   0.99
# 4                   3            1064                   0.94
#
#    favorite_category  avg_category_view_by_visit_last_m  unpaid_purch_qtr  \
# ...

# %%
customer_web_time.head()
# Out:
#    customer_id       period_name  time_spent_on_site_min
# 0       215348     текущий_месяц                      14
# 1       215348  предыдущий_месяц                      13
# 2       215349     текущий_месяц                      10
# 3       215349  предыдущий_месяц                      12
# 4       215350     текущий_месяц                      13

# %%
customer_value.head()
# Out:
#    customer_id          period_name  revenue
# 0       215348  препредыдущий_месяц      0.0
# 1       215348        текущий_месяц   3293.1
# 2       215348     предыдущий_месяц      0.0
# 3       215349  препредыдущий_месяц   4472.0
# 4       215349        текущий_месяц   4971.6

# %%
customer_profit.head()
# Out:
#    customer_id  customer_profit
# 0       215348             0.98
# 1       215349             4.16
# 2       215350             3.13
# 3       215351             4.87
# 4       215352             4.21

# %% [markdown]
# #### Вывод по предобработке данных
#
# Были выполнены следующие шаги:
#
# 1. Проверка на пропущенные значения: В результате проверки не обнаружено пропущенных значений в предоставленном наборе данных.
#
# 2. Коррекция данных: Выявлены и исправлены несоответствия в значениях некоторых столбцов, предположительно возникшие в результате опечаток.
#
# 3. Преобразование типов данных: Для оптимизации вычислительной эффективности и повышения точности анализа произведено преобразование типов данных.
#
# 4. Переименование столбцов: Названия некоторых столбцов были изменены для повышения читаемости и ясности.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные исследованы и обработаны.

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Исследуем дискретные и непрерывные переменные

# %%
# Список дискретных переменных для анализа
discrete_features_customer_web_beh = [
    'act_m_adv_activity',
    'avg_category_view_by_visit_last_m',
    'unpaid_purch_qtr', 
    'unpaid_purch_qtr',
    'site_crash_numb', 
    'pages_per_visits_3_m'
]

# Создаем фигуру с заданным размером
plt.figure(figsize=(24, 22))

# Перебираем дискретные признаки и строим для каждого countplot
for i, feature in enumerate(discrete_features_customer_web_beh, 1):
    # Создаем подграфик (subplot) на сетке 3x5. 
    # i - номер подграфика (от 1 до len(discrete_features_customer_web))
    plt.subplot(3, 5, i)
    
    # Строим countplot для текущего признака
    # customer_web_time_pivot - DataFrame, содержащий данные (не определен в предоставленном коде)
    sns.countplot(data=customer_web_beh, x=feature)
    
    # Устанавливаем заголовок подграфика
    plt.title(f'Распределение {feature}')

# Настраиваем расположение подграфиков, чтобы они не перекрывались
plt.tight_layout()

# Отображаем графики
plt.show()

# %%
# Список дискретных переменных для анализа
discrete_features_customer_web_beh = [
    'act_m_adv_activity',
    'avg_category_view_by_visit_last_m',
    'unpaid_purch_qtr', 
    'unpaid_purch_qtr',
    'site_crash_numb', 
    'pages_per_visits_3_m'
]

# Создаем фигуру с заданным размером
plt.figure(figsize=(24, 22))

# Перебираем дискретные признаки и строим для каждого countplot
for i, feature in enumerate(discrete_features_customer_web_beh, 1):
    # Создаем подграфик (subplot) на сетке 3x5. 
    # i - номер подграфика (от 1 до len(discrete_features_customer_web))
    plt.subplot(3, 5, i)
    
    # Строим countplot для текущего признака
    # customer_web_time_pivot - DataFrame, содержащий данные (не определен в предоставленном коде)
    sns.countplot(data=customer_web_beh, x=feature)
    
    # Устанавливаем заголовок подграфика
    plt.title(f'Распределение {feature}')

# Настраиваем расположение подграфиков, чтобы они не перекрывались
plt.tight_layout()

# Отображаем графики
plt.show()

# %%
# Список непрерывных переменных для анализа
continuous_columns_customer_web_beh = [
    '6_m_adv_activity', 
    'act_m_adv_activity', 
    'life_time_days',
    '%_promotion_purchases'
]

# Создаем фигуру и оси для всех графиков
fig, axes = plt.subplots(nrows=2, ncols=len(continuous_columns_customer_web_beh), figsize=(20, 10))
fig.tight_layout(pad=4.0)

# Объединение цикла для построения гистограмм и boxplot'ов
for i, feature in enumerate(continuous_columns_customer_web_beh):
    # Построение гистограммы и графика KDE
    sns.histplot(data=customer_web_beh, x=feature, kde=True, ax=axes[0, i])
    axes[0, i].set_title(f'Распределение {feature}')
    
    # Построение boxplot
    sns.boxplot(data=customer_web_beh, y=feature, ax=axes[1, i])
    axes[1, i].set_title(f'Boxplot для {feature}')

# Отображаем все графики
plt.show()

# %% [markdown]
# Преобразуем данных из "длинного" формата (отдельная строка для каждого периода) в "широкий" формат (отдельный столбец для каждого периода) с помощью функции pivot.

# %%
# Создаем DataFrame df_1, содержащий данные о времени, проведенном на сайте в предыдущем месяце
df_1 = customer_web_time[customer_web_time['period_name']=='предыдущий_месяц'].copy()
# Переименовываем столбец 'time_spent_on_site_min' в 'time_spent_on_site_min_previos_m'
df_1.rename(columns={'time_spent_on_site_min':'time_spent_on_site_min_m-1'},inplace=True)
# Удаляем столбец 'period_name'
df_1.drop('period_name', axis= 1 , inplace= True )

# Создаем DataFrame df_2, содержащий данные о времени, проведенном на сайте в текущем месяце
df_2 = customer_web_time[customer_web_time['period_name']=='текущий_месяц'].copy()
# Переименовываем столбец 'time_spent_on_site_min' в 'time_spent_on_site_min_actual_m'
df_2.rename(columns={'time_spent_on_site_min':'time_spent_on_site_min_m'},inplace=True)
# Удаляем столбец 'period_name'
df_2.drop('period_name', axis= 1 , inplace= True )

# Объединяем df_1 и df_2 по столбцу 'customer_id' с сортировкой
customer_web_time_pivot = pd.merge(df_1, df_2, on='customer_id', sort=True)

# Выводим информацию о DataFrame customer_web_time_pivot
print(customer_web_time_pivot.info())
# Выводим первые 5 строк DataFrame customer_web_time_pivot
customer_web_time_pivot.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 1300 non-null   int64
#  1   time_spent_on_site_min_m-1  1300 non-null   int64
#  2   time_spent_on_site_min_m    1300 non-null   int64
# dtypes: int64(3)
# memory usage: 40.6 KB
# None
#    customer_id  time_spent_on_site_min_m-1  time_spent_on_site_min_m
# 0       215348                          13                        14
# 1       215349                          12                        10
# 2       215350                           8                        13
# 3       215351                          11                        13
# 4       215352                           8                        11

# %%
# Список дискретных переменных для анализа
discrete_features_customer_web_time_pivot = [
    'time_spent_on_site_min_m',
    'time_spent_on_site_min_m-1',
]

# Создаем фигуру с заданным размером
plt.figure(figsize=(24, 22))

# Перебираем дискретные признаки и строим для каждого countplot
for i, feature in enumerate(discrete_features_customer_web_time_pivot, 1):
    # Создаем подграфик (subplot) на сетке 3x5. 
    # i - номер подграфика (от 1 до len(discrete_features_customer_web))
    plt.subplot(3, 5, i)
    
    # Строим countplot для текущего признака
    # customer_web_time_pivot - DataFrame, содержащий данные (не определен в предоставленном коде)
    sns.countplot(data=customer_web_time_pivot, x=feature)
    
    # Устанавливаем заголовок подграфика
    plt.title(f'Распределение {feature}')

# Настраиваем расположение подграфиков, чтобы они не перекрывались
plt.tight_layout()

# Отображаем графики
plt.show()

# %% [markdown]
# Преобразуем данных из "длинного" формата (отдельная строка для каждого периода) в "широкий" формат (отдельный столбец для каждого периода) с помощью функции pivot.

# %%
# Создаем DataFrame df_1 для текущего месяца
df_1 = customer_value[customer_value['period_name']=='текущий_месяц'].copy()
# Переименовываем столбец 'revenue' в 'revenue_m'
df_1.rename(columns={'revenue':'revenue_m'},inplace=True)
# Удаляем столбец 'period_name'
df_1.drop('period_name', axis= 1 , inplace= True )

# Создаем DataFrame df_2 для предыдущего месяца
df_2 = customer_value[customer_value['period_name']=='предыдущий_месяц'].copy()
# Переименовываем столбец 'revenue' в 'revenue_m-1'
df_2.rename(columns={'revenue':'revenue_m-1'},inplace=True)
# Удаляем столбец 'period_name'
df_2.drop('period_name', axis= 1 , inplace= True )

# Создаем DataFrame df_3 для препредыдущего месяца
df_3 = customer_value[customer_value['period_name']=='препредыдущий_месяц'].copy()
# Переименовываем столбец 'revenue' в 'revenue_m-2'
df_3.rename(columns={'revenue':'revenue_m-2'},inplace=True)
# Удаляем столбец 'period_name'
df_3.drop('period_name', axis= 1 , inplace= True )

# Объединяем df_1 и df_2 по 'customer_id'
customer_value_pivot = pd.merge(df_1, df_2, on='customer_id', sort=True)
# Объединяем результат с df_3 по 'customer_id'
customer_value_pivot = pd.merge(df_3, customer_value_pivot, on='customer_id', sort=True)

# Выводим информацию о DataFrame
print(customer_value_pivot.info())
# Выводим первые 5 строк DataFrame
customer_value_pivot.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1300 non-null   int64
#  1   revenue_m-2  1300 non-null   float64
#  2   revenue_m    1300 non-null   float64
#  3   revenue_m-1  1300 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 50.8 KB
# None
#    customer_id  revenue_m-2  revenue_m  revenue_m-1
# 0       215348          0.0     3293.1          0.0
# 1       215349       4472.0     4971.6       5216.0
# 2       215350       4826.0     5058.4       5457.5
# 3       215351       4793.0     6610.4       6158.0
# 4       215352       4594.0     5872.5       5807.5

# %%
# Список непрерывных переменных для анализа
continuous_columns_customer_value_pivot = [
    'revenue_m',
    'revenue_m-1',
    'revenue_m-2'
]

# Создаем фигуру для всех графиков; подмодулируем размеры для оптимальности
fig, axes = plt.subplots(2, len(continuous_columns_customer_value_pivot), figsize=(15, 8))
fig.tight_layout(pad=4.0)

# Цикл для построения гистограмм и графиков KDE и boxplot'ов
for i, feature in enumerate(continuous_columns_customer_value_pivot):
    # Построение гистограммы и графика KDE на верхней оси
    sns.histplot(data=customer_value_pivot, x=feature, kde=True, ax=axes[0, i])
    axes[0, i].set_title(f'Распределение {feature}')

    # Построение boxplot на нижней оси
    sns.boxplot(data=customer_value_pivot, y=feature, ax=axes[1, i])
    axes[1, i].set_title(f'Boxplot для {feature}')

# Отображаем все графики на одной фигуре
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для анализа дискретных признаков нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot`.
#
# Для этих признаков также не нужно строить ящики с усами, так как признак имеет, скорее, распределение категориального признака, пусть и представленного уже в численном виде.
#
# Дискретность признака определяется либо числом уникальных значений (обычно не более 20), либо отсутствием дробной части (дискретный признак всегда целочисленный).
#
# Из анализа также следует исключить признак `id` - для EDA он бесполезен.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Исправил, переработал все постоения графиков выше.*
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> `act_m_adv_activity` - также дискретный признак, для которого не нужна гистограмма и ящик с усами.

# %% [markdown]
# * Данные по маркетинговой активности есть по 1300 клиентам
#
# * `6_m_adv_activity`: Количество маркетинговых коммуникаций за последние 6 месяцев. В среднем покупатель получал 4.25 сообщения, со стандартным отклонением 1.01. Минимальное количество сообщений - 0.9, максимальное - 6.6. Медиана (50%) равна 4.2, что близко к среднему значению, указывая на относительно симметричное распределение.
# На гистограмме видно, что распределение данных 6_m_adv_activity имеет характерную форму, с наибольшей концентрацией значений в диапазоне от 3.5 до 5.5. Присутствует несколько выбросов в нижней части.
# Ящик с усами показывает, что медиана данного распределения находится около 4.4, а межквартильный размах (IQR) указывает на варьирование значений в пределах 4 до 5.5. Есть выбросы, но они не выглядят аномальными.
#
# * `act_m_adv_activity`: Количество маркетинговых коммуникаций в текущем месяце. Среднее значение - 4.01, что немного меньше, чем за последние 6 месяцев. Стандартное отклонение 0.69 меньше, чем у `6_m_adv_activity`, что говорит о меньшей вариативности коммуникаций в текущем месяце.
# На гистограмме видно, что распределение данных о переменной `act_m_adv_activity` , 3 группы со значениями 3, 4 и 5.
# Ящик с усами показывает эти же 3 группы.
#
# * `life_time_days`: Время жизни покупателя в днях (с момента регистрации). В среднем покупатель "живет" 601.9 дней. Большой разброс значений (стандартное отклонение 249.86) говорит о том, что в выборке есть как новые, так и давние покупатели.
# На гистограмме распределение выглядит нормальным, с максимумом вокруг 600 дней. Наибольшее количество наблюдений сосредоточено в диапазоне от 400 до 800 дней.
# На ящике с усами видно, что данные не содержат значительных выбросов.
#
# * `%_promotion_purchases`: Процент покупок, совершенных по промоакциям. В среднем 31.98% покупок совершается по промоакциям. Максимальное значение 0.99 (99%) указывает на покупателей, которые практически всегда покупают только по акциям.
# На гистограмме видно, что распределение процентных покупок по акциям имеет несколько пиков, с наиболее выраженным в диапазоне около 0.2.
# В ящике с усами медиана находится около 0.2. Присутствуют выбросы, что указывает на редкие случаи высоких значений, те наличие покупателей, которые совершают покупки только по акциям.
#
# * `avg_category_view_by_visit_last_m`: Среднее количество просмотров категорий товаров за одно посещение сайта в последний месяц. Среднее значение 3.27 говорит о том, что покупатели в среднем просматривают немного больше 3 категорий за визит.
#
# * `unpaid_purch_qtr`: Количество неоплаченных заказов за квартал. В среднем 2.84 неоплаченных заказа. Это важный показатель для анализа потенциальных проблем в процессе оформления заказа.
#
# * `site_crash_numb`: Количество сбоев сайта. В среднем 4.19 сбоя на пользователя. Это довольно высокий показатель, требующий внимания. Есть проблемы с технической стабильностью сайта.
#
# * `pages_per_visits_3_m`: Среднее количество просмотренных страниц за одно посещение сайта за последние 3 месяца. Среднее значение 8.18.
#
# * Данные по времения пребывания на сайте есть по 2600 клиентам
#
# * `time_spent_on_site_min`: Среднее время посещения составляет 13.34 минуты. Стандартное отклонение равно 4.08 Минимальное время, проведенное на сайте, составляет 4 минуты, а максимальное - 23 минуты. Медиана равна 13 минутам, что близко к среднему значению.
# Гистограмма показывает нормальное распределение времени, проведённого на сайте, с пиком около 15 минут. Распределение достаточно симметричное, с небольшими отклонениями в обе стороны.
# Длины усов показывают, что значительное количество пользователей провело от 10 до 20 минут на сайте, при этом нет значительных выбросов.
#
# * Данные по выручке есть данные по 3900 клиентам.
# * Средняя выручка на одного клиента составляет 5025.70 условных единиц. Стандартное отклонение равно 1777.70, что указывает на значительный разброс значений выручки вокруг среднего. Это говорит о том, что выручка от разных клиентов может существенно отличаться. Минимальная выручка равна 0. Это означает, что есть зарешгистрировавшиеся, кто ничего не купил.
# 25% клиентов принесли выручку 4590.15 условных единиц или меньше.
# Медианная выручка составляет 4957.50
# 75% клиентов принесли выручку 5363.00
# Максимальная выручка от одного клиента достигает 106862.20 условных единиц. Это значение значительно превышает среднюю выручку и скорее всего является неверным значением.Об этом же говорят гистограмма и ящик с усами этот выброс нужно обработать.
#
#
# * Данные по прибыли есть данные по 1300 клиентам.
# * Средняя прибыль на одного клиента составляет 3.996
# * Стандартное отклонение равно 1.013, что указывает на разброс значений прибыли вокруг среднего значения.
# * Минимальная прибыль с клиента составляет 0.86
# * 25% клиентов приносят прибыль 3.30
# * Медианна составляет 4.045 Половина клиентов приносит прибыль меньше или равную этой величине.
# * 75% клиентов приносят прибыль 4.67 условных единиц или меньше.
# * Максимальная прибыль с одного клиента составляет 7.43
#
# Гистограмма `customer_profit` распределение нормальное, с пиком около 4
# Ящик с усами показывает, что большинство клиентов имеют прибыль около 4, с некоторыми выбросами и более высокими значениями, основная масса сосредоточена в пределах от 3 до 5.

# %% [markdown]
# #### Удалим выброс

# %%
customer_value.head()
# Out:
#    customer_id          period_name  revenue
# 0       215348  препредыдущий_месяц      0.0
# 1       215348        текущий_месяц   3293.1
# 2       215348     предыдущий_месяц      0.0
# 3       215349  препредыдущий_месяц   4472.0
# 4       215349        текущий_месяц   4971.6

# %%
# Посмотрим на ТОП максимальных значений по убыванию
customer_value.sort_values(by='revenue', ascending=False).head()
# Out:
#       customer_id    period_name   revenue
# 98         215380  текущий_месяц  106862.2
# 435        215493  текущий_месяц    7799.4
# 262        215435  текущий_месяц    7605.3
# 1481       215841  текущий_месяц    7557.0
# 2388       216144  текущий_месяц    7547.8

# %%
# Оставим только значения меньше 8000, удалив тем самым выброс
customer_value = customer_value[customer_value['revenue'] < 8000]

# %%
# Проверим
customer_value.sort_values(by='revenue', ascending=False).head()
# Out:
#       customer_id    period_name  revenue
# 435        215493  текущий_месяц   7799.4
# 262        215435  текущий_месяц   7605.3
# 1481       215841  текущий_месяц   7557.0
# 2388       216144  текущий_месяц   7547.8
# 566        215536  текущий_месяц   7467.9

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исключён выброс по выручке.

# %% [markdown]
# #### Исследуем категориальные признаки

# %%
customer_web_beh.head()
# Out:
#    customer_id customer_activity service_type adv_permision  6_m_adv_activity  \
# 0       215348         Снизилась      премиум            да               3.4
# 1       215349         Снизилась      премиум            да               4.4
# 2       215350         Снизилась     стандарт           нет               4.9
# 3       215351         Снизилась     стандарт            да               3.2
# 4       215352         Снизилась     стандарт           нет               5.1
#
#    act_m_adv_activity  life_time_days  %_promotion_purchases  \
# 0                   5             121                   0.00
# 1                   4             819                   0.75
# 2                   3             539                   0.14
# 3                   5             896                   0.99
# 4                   3            1064                   0.94
#
#    favorite_category  avg_category_view_by_visit_last_m  unpaid_purch_qtr  \
# ...

# %%
customer_web_time.head()
# Out:
#    customer_id       period_name  time_spent_on_site_min
# 0       215348     текущий_месяц                      14
# 1       215348  предыдущий_месяц                      13
# 2       215349     текущий_месяц                      10
# 3       215349  предыдущий_месяц                      12
# 4       215350     текущий_месяц                      13

# %%
customer_value.head()
# Out:
#    customer_id          period_name  revenue
# 0       215348  препредыдущий_месяц      0.0
# 1       215348        текущий_месяц   3293.1
# 2       215348     предыдущий_месяц      0.0
# 3       215349  препредыдущий_месяц   4472.0
# 4       215349        текущий_месяц   4971.6

# %%
customer_profit.head()
# Out:
#    customer_id  customer_profit
# 0       215348             0.98
# 1       215349             4.16
# 2       215350             3.13
# 3       215351             4.87
# 4       215352             4.21

# %%
def visualize_categorical_data(customer_web_beh, customer_web_time, customer_value):
    # Списки категориальных колонок для каждого датафрейма
    customer_web_beh_categorical_columns = ['customer_activity', 'service_type', 'adv_permision', 'favorite_category']
    customer_web_time_categorical_columns = ['period_name']
    customer_value_categorical_columns = ['period_name']
    
    # Функция для построения графиков
    def plot_category_data(dataframe, column, title_prefix):
        plt.figure(figsize=(12, 5))
        
        # Гистограмма
        plt.subplot(1, 2, 1)
        sns.countplot(data=dataframe, x=column, order=dataframe[column].value_counts().index)
        plt.title(f"Гистограмма {title_prefix} {column}")
        plt.xticks(rotation=45)
        
        # Круговая диаграмма
        plt.subplot(1, 2, 2)
        dataframe[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set3')
        plt.ylabel('')  # Убираем название оси
        plt.title(f"Круговая диаграмма {title_prefix} {column}")
        
        plt.tight_layout()
        plt.show()

    # Визуализация customer_web_beh
    for column in customer_web_beh_categorical_columns :
        plot_category_data(customer_web_beh, column, "customer_web_beh")
    
    # Визуализация customer_web_time
    for column in customer_web_time_categorical_columns:
        plot_category_data(customer_web_time, column, "customer_web_time")
    
    # Визуализация customer_value_categorical
    for column in customer_value_categorical_columns:
        plot_category_data(customer_value, column, "customer_value")

visualize_categorical_data(customer_web_beh, customer_web_time, customer_value)

# %% [markdown]
# * Уровень активности клиентов в основном находится на "Прежнем уровне", который составляет 61.7%, по сравнению с 38.3% для категории "Снизилась".
#
# * Большинство клиентов, дали согласие на получение рекламы (True), в то время как только около 200 человек отказались (False), 74% клиентов согласны, в то время как 26% - нет.
#
# * Наиболее популярная категория товаров — это «Товары для детей», за которой следуют «Домашний текстиль» и «Косметика и аксессуары». «Товары для детей» - 25.4%, «Домашний текстиль» с 19.3% и «Косметика и аксессуары»  17.2%, «Техника для красоты и здоровья» 14.2%, «Мелкая бытовая техника и электроника» 13.4%
#
# * Количество наблюдений для обоих месяцев по 50%.
#
# * Распределение клиентов по трем рассмотренным периодам: все три категории показывают равное количество клиентов - 1200, что составляет 33.3%.

# %% [markdown]
# #### Общий вывод по иссдедовательскому анализу:
#
# * Интересно, что среднее количество маркетинговых коммуникаций за 6 месяцев и за текущий месяц практически одинаково. Это может говорить о стабильной маркетинговой стратегии. Стоит проанализировать, коррелирует ли количество коммуникаций с конверсией и другими важными метриками (например, с количеством покупок или суммой чека). Возможно, для некоторых клиентов 4 сообщения в месяц — это слишком много, а для других — слишком мало. Сегментация аудитории и персонализация коммуникаций могут повысить эффективность маркетинга.
# * Высокий процент покупок по промоакциям может указывать на то, что клиенты привыкли к скидкам и не совершают покупки по полной цене. Это может негативно сказаться на прибыли. Необходимо проанализировать эффективность промоакций и, возможно, пересмотреть стратегию, предложив альтернативные стимулы для покупок.
#
# * Высокий показатель сбоев сайта (4.19 на пользователя) — серьезная проблема, требующая решения. Сбои сайта приводят к потере клиентов и негативно влияют на репутацию компании. Необходимо устранить технические проблемы.
# * В среднем 8 просмотренных страниц за визит, 3 просмотренные категории и 13 минут на сайте — неплохие показатели, но их всегда можно улучшить.
#
# Анализ поведения пользователей на сайте (например, с помощью веб-аналитики) поможет выявить точки роста и оптимизировать пользовательский опыт.
#
# Необходимо выяснить причины, по которым клиенты не завершают покупки. Это могут быть технические проблемы, сложный процесс оформления заказа, недостаточная информация о товаре или доставке, высокие цены и т.д.
#
# Для более глубокого анализа данных стоит провести сегментацию клиентов по по времени жизни, активности, количеству покупок, предпочитаемым категориям товаров и проанализировать показатели для каждой группы. Это поможет выявить особенности поведения разных сегментов клиентов и разработать более эффективные маркетинговые стратегии.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный EDA признаков - молодец, что используешь разные инструменты для анализа признаков разного типа.

# %% [markdown]
# #### Отберем клиентов с покупательской активностью не менее трёх месяцев, то с выручкой больше нуля все три месяца.

# %%
customer_value_3_m = customer_value[customer_value.customer_id.isin(customer_value.query('revenue==0')['customer_id'].unique())==False]

# %%
customer_value_3_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3890 entries, 3 to 3899
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  3890 non-null   int64
#  1   period_name  3890 non-null   object
#  2   revenue      3890 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 121.6+ KB

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исключены неактивные пользователи.

# %% [markdown]
# #### Итог по исследовательскому анализу
# 1. Распределение данных:
#
# * Большинство представленных данных следует нормальному распределению.
# * В большинстве наборов данных обнаружены выбросы.
# * Причины выбросов:
#     * Сезонность продаж.
#     * Особенности поведения отдельных покупателей.
#     * Возможные ошибки ввода данных.
# * Критически большой выброс был удален.
#
# 2. Ключевые выводы:
#
# * Популярность категорий: "Товары для детей" составляют значительную долю покупок.
# * Большинство клиентов согласились на рекламную рассылку.
# * Большинство клиентов используют стандартный тип сервиса.
# * Большинство покупателей сохранили свою активность.
#
# 3. Выбраны активных пользователей за последние 3 месяца, список покупателей (3891) доступен в датафрейме `customer_value_3_m`.

# %% [markdown]
# ### Объединение таблиц

# %% [markdown]
# #### Cделаем отдельные столбецы для каждого периода.

# %% [markdown]
# Объединим таблицы, структурировав данные по выручке и времени на сайте для каждого отчетного периода (предыдущий месяц, текущий месяц, предпредыдущий месяц) в отдельных столбцах.
#
# Преобразуем данных из "длинного" формата (отдельная строка для каждого периода) в "широкий" формат (отдельный столбец для каждого периода) с помощью функции `pivot`.

# %% [markdown]
# visualize_categorical_data(customer_web_beh, customer_web_time, customer_value)

# %%
customer_web_time.head()
# Out:
#    customer_id       period_name  time_spent_on_site_min
# 0       215348     текущий_месяц                      14
# 1       215348  предыдущий_месяц                      13
# 2       215349     текущий_месяц                      10
# 3       215349  предыдущий_месяц                      12
# 4       215350     текущий_месяц                      13

# %%
print(customer_web_time.info(), '\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             2600 non-null   int64
#  1   period_name             2600 non-null   object
#  2   time_spent_on_site_min  2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# None

# %%
# Создаем DataFrame df_1, содержащий данные о времени, проведенном на сайте в предыдущем месяце
df_1 = customer_web_time[customer_web_time['period_name']=='предыдущий_месяц'].copy()
# Переименовываем столбец 'time_spent_on_site_min' в 'time_spent_on_site_min_previos_m'
df_1.rename(columns={'time_spent_on_site_min':'time_spent_on_site_min_m-1'},inplace=True)
# Удаляем столбец 'period_name'
df_1.drop('period_name', axis= 1 , inplace= True )

# Создаем DataFrame df_2, содержащий данные о времени, проведенном на сайте в текущем месяце
df_2 = customer_web_time[customer_web_time['period_name']=='текущий_месяц'].copy()
# Переименовываем столбец 'time_spent_on_site_min' в 'time_spent_on_site_min_actual_m'
df_2.rename(columns={'time_spent_on_site_min':'time_spent_on_site_min_m'},inplace=True)
# Удаляем столбец 'period_name'
df_2.drop('period_name', axis= 1 , inplace= True )

# Объединяем df_1 и df_2 по столбцу 'customer_id' с сортировкой
customer_web_time_pivot = pd.merge(df_1, df_2, on='customer_id', sort=True)

# Выводим информацию о DataFrame customer_web_time_pivot
print(customer_web_time_pivot.info())
# Выводим первые 5 строк DataFrame customer_web_time_pivot
customer_web_time_pivot.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 1300 non-null   int64
#  1   time_spent_on_site_min_m-1  1300 non-null   int64
#  2   time_spent_on_site_min_m    1300 non-null   int64
# dtypes: int64(3)
# memory usage: 40.6 KB
# None
#    customer_id  time_spent_on_site_min_m-1  time_spent_on_site_min_m
# 0       215348                          13                        14
# 1       215349                          12                        10
# 2       215350                           8                        13
# 3       215351                          11                        13
# 4       215352                           8                        11

# %%
print(customer_value.info(), '\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3899 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  3899 non-null   int64
#  1   period_name  3899 non-null   object
#  2   revenue      3899 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 121.8+ KB
# None

# %%
customer_value.head()
# Out:
#    customer_id          period_name  revenue
# 0       215348  препредыдущий_месяц      0.0
# 1       215348        текущий_месяц   3293.1
# 2       215348     предыдущий_месяц      0.0
# 3       215349  препредыдущий_месяц   4472.0
# 4       215349        текущий_месяц   4971.6

# %% [markdown]
# #### Объединим датафреймы

# %%
merged_data = pd.merge(customer_value_pivot, pd.merge(customer_web_time_pivot, customer_web_beh, on='customer_id', sort=True), on='customer_id', sort=True)
print(merged_data.info())
merged_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   customer_id                        1300 non-null   int64
#  1   revenue_m-2                        1300 non-null   float64
#  2   revenue_m                          1300 non-null   float64
#  3   revenue_m-1                        1300 non-null   float64
#  4   time_spent_on_site_min_m-1         1300 non-null   int64
#  5   time_spent_on_site_min_m           1300 non-null   int64
#  6   customer_activity                  1300 non-null   object
#  7   service_type                       1300 non-null   object
#  8   adv_permision                      1300 non-null   object
#  9   6_m_adv_activity                   1300 non-null   float64
#  10  act_m_adv_activity                 1300 non-null   int64
# ...

# %% [markdown]
# #### Итог по объединению таблиц
# Данные успешно объедены, проведено преобразование данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные соединены корректно.

# %% [markdown]
# ### Корреляционный анализ

# %% [markdown]
# Проведем корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделаем выводы о мультиколлинеарности и при необходимости устраним её.

# %%
merged_data.head()
# Out:
#    customer_id  revenue_m-2  revenue_m  revenue_m-1  \
# 0       215348          0.0     3293.1          0.0
# 1       215349       4472.0     4971.6       5216.0
# 2       215350       4826.0     5058.4       5457.5
# 3       215351       4793.0     6610.4       6158.0
# 4       215352       4594.0     5872.5       5807.5
#
#    time_spent_on_site_min_m-1  time_spent_on_site_min_m customer_activity  \
# 0                          13                        14         Снизилась
# 1                          12                        10         Снизилась
# 2                           8                        13         Снизилась
# 3                          11                        13         Снизилась
# 4                           8                        11         Снизилась
#
#   service_type adv_permision  6_m_adv_activity  act_m_adv_activity  \
# 0      премиум            да               3.4                   5
# 1      премиум            да               4.4                   4
# ...

# %%
merged_data = merged_data.sort_values(by=['customer_id']).set_index('customer_id')

# %%
# Исключаем 'id' из данных
columns_for_corr = [col for col in merged_data.columns if col != 'customer_id']
filtered_data = merged_data[columns_for_corr]

# %%
# Вычисляем корреляционную матрицу Спирмена
correlation_matrix = filtered_data.corr(method="spearman", numeric_only=True)

# Создаем фигуру и оси для графика
fig, ax = plt.subplots(figsize=(11, 10))

# Устанавливаем заголовок графика
plt.suptitle('Матрица корреляции Спирмена количественных значений')

# Строим тепловую карту корреляционной матрицы
sns.heatmap(correlation_matrix, 
            annot=True, 
            cmap='coolwarm')

# Отображаем график
plt.show()

# %% [markdown]
# Построим тепловую карту корреляции phi(k) для количественных данных распределение которых ненормальное с выбросами.

# %%
display(filtered_data.head())
# Out:
#              revenue_m-2  revenue_m  revenue_m-1  time_spent_on_site_min_m-1  \
# customer_id
# 215348               0.0     3293.1          0.0                          13
# 215349            4472.0     4971.6       5216.0                          12
# 215350            4826.0     5058.4       5457.5                           8
# 215351            4793.0     6610.4       6158.0                          11
# 215352            4594.0     5872.5       5807.5                           8
#
#              time_spent_on_site_min_m customer_activity service_type  \
# customer_id
# 215348                             14         Снизилась      премиум
# 215349                             10         Снизилась      премиум
# 215350                             13         Снизилась     стандарт
# 215351                             13         Снизилась     стандарт
# 215352                             11         Снизилась     стандарт
#
# ...

# %%
# Определяем список столбцов с интервальными данными, укажем непрерывные признаки
interval_cols = [
    'revenue_m-2',
    'revenue_m-1',
    'revenue_m',
    'life_time_days',
    '%_promotion_purchases',
    '6_m_adv_activity'
]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `6_m_adv_activity` - также непрерывный признак, который нужно передавать в `interval_cols`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Исправил*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Создаем фигуру и оси для графика
fig, ax = plt.subplots(figsize=(11, 10))

# Устанавливаем заголовок графика
plt.suptitle('Матрица корреляции phi(k) всех столбцов')

# Строим тепловую карту корреляционной матрицы phik
sns.heatmap(
    filtered_data.phik_matrix(interval_cols=interval_cols), # Вычисляем корреляционную матрицу phik, указывая интервальные столбцы
    annot=True, # Отображаем значения корреляции на тепловой карте
    cmap='coolwarm'
);

plt.show()

# %% [markdown]
# #### Вывод по корреляционному анализу:
#
# * Мультиколлинеарность: Отсутствует мультиколлинеарность, так как между входными параметрами не обнаружено корреляций выше 0.9.
#
# * Корреляция Спирмена: Максимальное значение корреляции Спирмена составляет 0.88. Этот коэффициент измеряет монотонную связь между переменными.
#
# * Корреляция Phi_k (φk): Максимальное значение корреляции Phi_k составляет 0.84. Phi_k учитывает нелинейные зависимости и приближается к коэффициенту корреляции Пирсона в случае бинарного нормального распределения входных данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Есть анализ корреляции - молодец, что используешь `phik` для анализа и нелинейных зависимостей, а также настраиваешь `interval_cols` для корректной оценки корреляции для переменных разного типа.

# %% [markdown]
# ### Использование пайплайнов

# %%
merged_data.head()
# Out:
#              revenue_m-2  revenue_m  revenue_m-1  time_spent_on_site_min_m-1  \
# customer_id
# 215348               0.0     3293.1          0.0                          13
# 215349            4472.0     4971.6       5216.0                          12
# 215350            4826.0     5058.4       5457.5                           8
# 215351            4793.0     6610.4       6158.0                          11
# 215352            4594.0     5872.5       5807.5                           8
#
#              time_spent_on_site_min_m customer_activity service_type  \
# customer_id
# 215348                             14         Снизилась      премиум
# 215349                             10         Снизилась      премиум
# 215350                             13         Снизилась     стандарт
# 215351                             13         Снизилась     стандарт
# 215352                             11         Снизилась     стандарт
#
# ...

# %% [markdown]
# #### Подготовка данных

# %%
# Устанавливаем random_state для воспроизводимости результатов
RANDOM_STATE = 42

# Разделяем данные на признаки (X) и целевую переменную (y)
X = merged_data.drop(['customer_activity'], axis=1) # Признаки (все столбцы, кроме 'customer_activity')
y = merged_data['customer_activity']              # Целевая переменная ('customer_activity')




# Разделяем данные на обучающую и тестовую выборки с учетом стратификации
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.25,      # Размер тестовой выборки (25%)
    random_state=RANDOM_STATE, # Random state для воспроизводимости
    stratify=y           # Стратификация по целевой переменной для сохранения пропорций классов
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сплитование выполнено корректно. Молодец, что делаешь стратификацю целевого признака - в выборках будет равное соотношение классов, что может привести к росту качества твоего решения.

# %%
# Выводим размеры полученных выборок
display(X_train.shape, X_test.shape, y_train.shape, y_test.shape)


# Создаем экземпляр LabelEncoder для кодирования целевой переменной
le = LabelEncoder()


# Обучаем LabelEncoder на уникальных значениях обучающей выборки
le.fit_transform(y_train.unique())

# Выводим соответствие между исходными значениями и закодированными
print('Значениям', le.classes_, 'назначено соответственно', le.transform(le.classes_))


# Кодируем целевую переменную в обучающей и тестовой выборках
y_train = le.transform(y_train)
y_test = le.transform(y_test)
# Out:
# (975, 16)
# (325, 16)
# (975,)
# (325,)
# Значениям ['Прежний уровень' 'Снизилась'] назначено соответственно [0 1]

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что используешь `LabelEncoder` для кодирования целевого признака.

# %% [markdown]
# #### Создадим списки с названиями признаков

# %%
# Список столбцов для one-hot encoding
ohe_columns = ['favorite_category'] 

# Список столбцов для ordinal encoding
ord_columns = ['service_type', 'adv_permision']

# %%
merged_data['service_type'].unique()
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %%
merged_data['adv_permision'].unique()
# Out:
# array(['да', 'нет'], dtype=object)

# %%
merged_data.head()
# Out:
#              revenue_m-2  revenue_m  revenue_m-1  time_spent_on_site_min_m-1  \
# customer_id
# 215348               0.0     3293.1          0.0                          13
# 215349            4472.0     4971.6       5216.0                          12
# 215350            4826.0     5058.4       5457.5                           8
# 215351            4793.0     6610.4       6158.0                          11
# 215352            4594.0     5872.5       5807.5                           8
#
#              time_spent_on_site_min_m customer_activity service_type  \
# customer_id
# 215348                             14         Снизилась      премиум
# 215349                             10         Снизилась      премиум
# 215350                             13         Снизилась     стандарт
# 215351                             13         Снизилась     стандарт
# 215352                             11         Снизилась     стандарт
#
# ...

# %%
# Список числовых столбцов
num_columns = ['revenue_m-2',       
               'revenue_m',          
               'revenue_m-1',             
               'time_spent_on_site_min_m-1',            
               'time_spent_on_site_min_m',
               '6_m_adv_activity',
               'act_m_adv_activity',                
               'life_time_days',                        
               '%_promotion_purchases',                   
               'avg_category_view_by_visit_last_m',
               'unpaid_purch_qtr',  
               'site_crash_numb',                      
               'pages_per_visits_3_m']

# %%
# Пайплайн для one-hot encoding (OHE): заполнение пропусков + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
# Пайплайн для ordinal encoding (OE): заполнение пропусков + OE + заполнение пропусков после OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'],
                    ['да', 'нет'],
                    
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
# Объединяем пайплайны для разных типов признаков в один с помощью ColumnTransformer
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# #### Обучим и сравним четыре модели классификации:
# * K-ближайших соседей (`KNeighborsClassifier`)
# * Дерево решений (`DecisionTreeClassifier`)
# * Логистическую регрессию (`LogisticRegression`)
# * Опорные вектора (`SVC`)
#
# Для оценки их производительности воспользуемся метрикой ROC-AUC. Это позволит оценить, насколько хорошо каждая модель различает классы, независимо от выбранного порога классификации.
# Цель — получить модель с ROC-AUC, максимально приближенную к 1, на тестовой выборке, что будет свидетельствовать о высокой точности предсказаний.
# Построим ROC-кривую, чтобы визуализировать соотношение истинных и ложных срабатываний при разных порогах, а значение AUC (площадь под кривой ROC) позволит мне суммировать производительность модели для всех возможных порогов.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выбор метрики для оценки модели обоснован.

# %% [markdown]
# ##### K-ближайших соседей (KNeighborsClassifier)

# %%
# Создаём итоговый пайплайн: объединение подготовки данных и модели в единый процесс
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),  # Шаг предварительной обработки данных
    ('models', KNeighborsClassifier())  # Шаг модели с использованием классификатора K-ближайших соседей
])

# Определение сетки параметров для гиперпараметрического поиска
param_grid = [
    # Словарь параметров для модели KNeighborsClassifier()
    {
        'models': [KNeighborsClassifier()],  # Используемая модель K-ближайших соседей
        'models__n_neighbors': range(2, 20),  # Диапазон значений числа соседей n_neighbors
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],  # Методы масштабирования данных
    }
]

# Настройка RandomizedSearchCV для подбора гиперпараметров, использующая pipe_final как пайплайн
knc = RandomizedSearchCV(
    pipe_final,  # Пайплайн, состоящий из предварительной обработки и модели
    param_grid,  # Сетка гиперпараметров для поиска
    cv=5,  # Использование 5-кратной кросс-валидации
    scoring='roc_auc',  # Использование ROC-AUC в качестве метрики для оценки
    random_state=RANDOM_STATE,  # Установка начального состояния для воспроизводимости
    n_jobs=-1  # Использование всех доступных процессоров для расчета
)

# Обучение модели с использованием RandomizedSearchCV
knc.fit(X_train, y_train)

# Вывод лучшей модели и её параметров
print('Лучшая модель и её параметры:\n\n', knc.best_estimator_)
# Вывод значения метрики ROC-AUC для лучшей модели на кросс-валидации
print('Метрика ROC-AUC лучшей модели на кросс - валидации:', knc.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['favorite_category']),
#                                                  ('ord',
# ...

# %%
# Создадим DataFrame из результатов кросс-валидации модели knc
choosing_model_separately = pd.DataFrame(knc.cv_results_).sort_values(
    # Сортируем DataFrame по столбцу 'rank_test_score' (ранг модели по результатам теста) в порядке возрастания
    by=['rank_test_score']
).head(1) # Выбираем только лучшую модель (первую строку после сортировки)

# Выбираем столбцы 'rank_test_score', 'param_models', 'mean_test_score' и 'params' из DataFrame
choosing_model_separately[['rank_test_score', 'param_models', 'mean_test_score', 'params']]
# Out:
#    rank_test_score            param_models  mean_test_score  \
# 9                1  KNeighborsClassifier()         0.908766
#
#                                               params
# 9  {'preprocessor__num': RobustScaler(), 'models_...

# %% [markdown]
# #### Дерево решений (DecisionTreeClassifier)

# %%
# Создаём итоговый пайплайн: объединение подготовки данных и модели в единый процесс
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),  # Шаг предварительной обработки данных
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))  # Шаг модели с использованием классификатора дерева решений
])

# Определение сетки параметров для гиперпараметрического поиска
param_grid = [
    # Словарь параметров для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],  # Используемая модель дерева решений
        'models__max_depth': range(1, 500),  # Диапазон значений максимальной глубины дерева
        'models__max_features': range(1, 20),  # Диапазон возможных значений для max_features
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],  # Методы масштабирования данных
    }
]

# Настройка RandomizedSearchCV для подбора гиперпараметров, использующая pipe_final как пайплайн
dtc = RandomizedSearchCV(
    pipe_final,  # Пайплайн, состоящий из предварительной обработки и модели
    param_grid,  # Сетка гиперпараметров для поиска
    cv=5,  # Использование 5-кратной кросс-валидации
    scoring='roc_auc',  # Использование ROC-AUC в качестве метрики для оценки
    random_state=RANDOM_STATE,  # Установка начального состояния для воспроизводимости
    n_jobs=-1  # Использование всех доступных процессоров для расчета
)

# Обучение модели с использованием RandomizedSearchCV
dtc.fit(X_train, y_train)

# Вывод лучшей модели и её параметров
print('Лучшая модель и её параметры:\n\n', dtc.best_estimator_)
# Вывод значения метрики ROC-AUC для лучшей модели на кросс-валидации
print('Метрика ROC-AUC лучшей модели на кросс - валидации:', dtc.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['favorite_category']),
#                                                  ('ord',
# ...

# %%
# Создаем DataFrame из результатов кросс-валидации модели dtc
choosing_model_1 = pd.DataFrame(dtc.cv_results_).sort_values(by=['rank_test_score']).head(1) 
# Объединм два DataFrame: choosing_model_separately (содержащий результаты для одной модели) и choosing_model_1 (содержащий результаты для другой модели)
# ignore_index=True сбросим индекс, чтобы избежать дублирования индексов
choosing_model_separately = pd.concat([choosing_model_separately, choosing_model_1], ignore_index= True ) 
# Выбирем столбцы 'rank_test_score', 'param_models', 'mean_test_score' и 'params' из объединенного DataFrame
choosing_model_separately[['rank_test_score', 'param_models', 'mean_test_score', 'params']]
# Out:
#    rank_test_score                             param_models  mean_test_score  \
# 0                1                   KNeighborsClassifier()         0.908766
# 1                1  DecisionTreeClassifier(random_state=42)         0.811930
#
#                                               params
# 0  {'preprocessor__num': RobustScaler(), 'models_...
# 1  {'preprocessor__num': RobustScaler(), 'models_...

# %% [markdown]
# ##### Логистическую регрессия (`LogisticRegression`)

# %%
# Создаём итоговый пайплайн: объединение подготовки данных и модели в один процесс
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),  # Шаг предварительной обработки данных
    ('models', LogisticRegression(random_state=RANDOM_STATE, solver='liblinear', penalty='l1'))  # Шаг модели с использованием регуляризации L1
])

# Определение сетки параметров для гиперпараметрического поиска
param_grid = [
    # Словарь параметров для модели LogisticRegression()
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear', penalty='l1')],  # Используемая модель логистической регрессии
        'models__C': range(1, 15),  # Диапазон значений параметра регуляризации C
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],  # Методы масштабирования данных
    }
]

# Настройка RandomizedSearchCV для подбора гиперпараметров, использующая pipe_final как пайплайн
lr = RandomizedSearchCV(
    pipe_final,  # Пайплайн, состоящий из предварительной обработки и модели
    param_grid,  # Сетка гиперпараметров для поиска
    cv=5,  # Использование 5-кратной кросс-валидации
    scoring='roc_auc',  # Использование ROC-AUC в качестве метрики для оценки
    random_state=RANDOM_STATE,  # Установка начального состояния для воспроизводимости
    n_jobs=-1  # Использование всех доступных процессоров для расчета
)

# Обучение модели с использованием RandomizedSearchCV
lr.fit(X_train, y_train)

# Вывод лучшей модели и её параметров
print('Лучшая модель и её параметры:\n\n', lr.best_estimator_)
# Вывод значения метрики ROC-AUC для лучшей модели на кросс-валидации
print('Метрика ROC-AUC лучшей модели на кросс - валидации:', lr.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['favorite_category']),
#                                                  ('ord',
# ...

# %%
# Создаем DataFrame из результатов кросс-валидации модели svc
choosing_model_1 = pd.DataFrame(lr.cv_results_).sort_values(by=['rank_test_score']).head(1) 
# Объединим два DataFrame: choosing_model_separately и choosing_model_1, игнорируя индексы
choosing_model_separately = pd.concat([choosing_model_separately, choosing_model_1], ignore_index= True ) 
# Выбирем столбцы и сортируем DataFrame по среднему значению тестового показателя ('mean_test_score') в порядке убывания
choosing_model_separately[['rank_test_score', 'param_models', 'mean_test_score', 'params']].sort_values(by=['mean_test_score'], ascending = False)
# Out:
#    rank_test_score                                       param_models  \
# 0                1                             KNeighborsClassifier()
# 2                1  LogisticRegression(penalty='l1', random_state=...
# 1                1            DecisionTreeClassifier(random_state=42)
#
#    mean_test_score                                             params
# 0         0.908766  {'preprocessor__num': RobustScaler(), 'models_...
# 2         0.901969  {'preprocessor__num': MinMaxScaler(), 'models_...
# 1         0.811930  {'preprocessor__num': RobustScaler(), 'models_...

# %% [markdown]
# ##### Опорные вектора (`SVC`)

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', SVC(random_state=RANDOM_STATE, probability=True))
])

# %%
# Определение сетки параметров для гиперпараметрического поиска
param_grid = [
    # Словарь параметров для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True)],
        'models__kernel': ['poly', 'rbf', 'sigmoid'],  # Различные ядра для SVC
        'models__degree': range(1, 15),  # Диапазон значений степени для полиномиального ядра
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],  # Различные методы масштабирования данных
    }
]

# Настройка RandomizedSearchCV для подбора гиперпараметров, использующих pipe_final в качестве пайплайна
svc = RandomizedSearchCV(
    pipe_final,  # Пайплайн, состоящий из предварительной обработки и модели
    param_grid,  # Сетка гиперпараметров для поиска
    cv=5,  # Использование 5-кратной кросс-валидации
    scoring='roc_auc',  # Использование AUC-ROC в качестве метрики для оценки
    random_state=RANDOM_STATE,  # Установка начального состояния для воспроизводимости
    n_jobs=-1  # Использование всех доступных процессоров для расчета
)

# Обучение модели с помощью RandomizedSearchCV
svc.fit(X_train, y_train)

# Вывод лучшей модели и её параметров
print('Лучшая модель и её параметры:\n\n', svc.best_estimator_)
# Вывод значения метрики ROC-AUC для лучшей модели на кросс-валидации
print('Метрика ROC-AUC лучшей модели на кросс - валидации:', svc.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['favorite_category']),
#                                                  ('ord',
# ...

# %%
# Создание DataFrame из результатов перекрестной проверки svc и выбор строки с наивысшим ранжированием test_score
choosing_model_1 = pd.DataFrame(svc.cv_results_).sort_values(by=['rank_test_score']).head(1)

# Объединение DataFrame choosing_model_separately и choosing_model_1, игнорируя исходные индексы
choosing_model_separately = pd.concat([choosing_model_separately, choosing_model_1], ignore_index=True)

# Выбор и сортировка столбцов по убыванию
choosing_model_separately[['rank_test_score', 'param_models', 'mean_test_score', 'params']].sort_values(by=['mean_test_score'], ascending=False)
# Out:
#    rank_test_score                                       param_models  \
# 3                1             SVC(probability=True, random_state=42)
# 0                1                             KNeighborsClassifier()
# 2                1  LogisticRegression(penalty='l1', random_state=...
# 1                1            DecisionTreeClassifier(random_state=42)
#
#    mean_test_score                                             params
# 3         0.917511  {'preprocessor__num': RobustScaler(), 'models_...
# 0         0.908766  {'preprocessor__num': RobustScaler(), 'models_...
# 2         0.901969  {'preprocessor__num': MinMaxScaler(), 'models_...
# 1         0.811930  {'preprocessor__num': RobustScaler(), 'models_...

# %% [markdown]
# #### Определим лучшую модель, используя результаты обучения и выбранную метрику.

# %% [markdown]
# Выбор модели осуществим по лучшему значению метрики на кросс - валидации.

# %%
# Сортировка DataFrame по 'mean_test_score' в порядке убывания и выбор первой строки
choosing_model_separately = choosing_model_separately.sort_values(by=['mean_test_score'], ascending=False).head(1)

# Выбор и отображение следующих столбцов: 'param_models', 'params', 'mean_test_score'
choosing_model_separately[[
    'param_models',
    'params',
    'mean_test_score'
]]
# Out:
#                              param_models  \
# 3  SVC(probability=True, random_state=42)
#
#                                               params  mean_test_score
# 3  {'preprocessor__num': RobustScaler(), 'models_...         0.917511

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучша ямодель.

# %%
# Вывод площади под ROC-кривой, рассчитанной на данных кросс-валидации
print('Площадь ROC-кривой на кросс-валидации:', svc.best_score_)

# Расчет площади под ROC-кривой на тестовой выборке
roc_auc_svc_test = roc_auc_score(y_test, svc.predict_proba(X_test)[:, 1])

# Вывод площади под ROC-кривой на тестовой выборке
print('Площадь ROC-кривой на тестовой выборке:', roc_auc_svc_test)

# Расчет потери качества на тестовой выборке в процентах относительно кросс-валидации
roc_auc_svc_km = (roc_auc_svc_test - svc.best_score_) / svc.best_score_ * 100

# Вывод потери качества на тестовой выборке в процентах
print(f'Потеря качества на тестовой выборке  = {roc_auc_svc_km:.2f} %')
# Out:
# Площадь ROC-кривой на кросс-валидации: 0.917510609783337
# Площадь ROC-кривой на тестовой выборке: 0.9084015406836783
# Потеря качества на тестовой выборке  = -0.99 %

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyClassifier` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html#sklearn.dummy.DummyClassifier) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.
#
# Константная модель оценивается так же, как и любая другая модель - обучаем её на `train`, делаем предсказания для `test` и оцениваем их качество. Ничего сложного, я уверен, у тебя получится, а наличие проверки на адекватность повышает ценность твоего исследования:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Добавил, ниже*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Разделяем данные на обучающую и тестовую выборки с учетом стратификации
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(
    X, y, 
    test_size=0.25,      # Размер тестовой выборки (25%)
    random_state=RANDOM_STATE, # Random state для воспроизводимости
    stratify=y           # Стратификация по целевой переменной
)

# Результаты
print("Размеры выборок:")
print(f"Обучающая выборка: X_train_2: {X_train_2.shape}, y_train: {y_train_2.shape}")
print(f"Тестовая выборка: X_test_2: {X_test_2.shape}, y_test: {y_test_2.shape}")

# Создаем экземпляр LabelEncoder для кодирования целевой переменной
le = LabelEncoder()

# Обучаем LabelEncoder на обучающей выборке
y_train_2_encoded = le.fit_transform(y_train)
y_test_2_encoded = le.transform(y_test)

# Выводим соответствие между исходными значениями и закодированными
print(f'Значениям {le.classes_} назначено соответственно {le.transform(le.classes_)}')

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Повторно сплитовать и кодировать данные не нужно - мы можем использовать те же данные для оценки, что подготовили ранее.

# %%
# Создание экземпляра DummyClassifier с стратегией 'stratified'
dummy_class = DummyClassifier(strategy='stratified', random_state=RANDOM_STATE)
dummy_class.fit(X_train_2, y_train_2_encoded)

# Вычисление и вывод значения ROC-AUC для DummyClassifier на обучающей выборке
roc_auc_dummy_train_2 = roc_auc_score(y_train_2_encoded, dummy_class.predict_proba(X_train_2)[:, 1])
print(f'Значение ROC-AUC модели "DummyClassifier" на обучающей выборке: {round(roc_auc_dummy_train_2, 4)}')

# Вычисление и вывод значения ROC-AUC для DummyClassifier на тестовой выборке
roc_auc_dummy_test_2 = roc_auc_score(y_test_2_encoded, dummy_class.predict_proba(X_test_2)[:, 1])
print(f'Значение ROC-AUC модели "DummyClassifier" на тестовой выборке: {round(roc_auc_dummy_test_2, 4)}')
# Out:
# Размеры выборок:
# Обучающая выборка: X_train_2: (975, 16), y_train: (975,)
# Тестовая выборка: X_test_2: (325, 16), y_test: (325,)
# Значениям [0 1] назначено соответственно [0 1]
# Значение ROC-AUC модели "DummyClassifier" на обучающей выборке: 0.5081
# Значение ROC-AUC модели "DummyClassifier" на тестовой выборке: 0.497

# %% [markdown]
# - ROC-AUC для лучшей модели: 0.911237
# - Лучшая модель значительно лучше константной модели.

# %%
# Присвоение значения для roc_auc_svc_cv
roc_auc_svc_cv = svc.best_score_


# Масштабируем значения AUC-ROC в проценты
roc_auc_svc_cv *= 100
roc_auc_svc_test *= 100

# Данные для графика
metrics = ['Кросс-валидация', 'Тестовая выборка', 'Потеря качества']
values = [roc_auc_svc_cv, roc_auc_svc_test, roc_auc_svc_km]

# Создание столбчатой диаграммы
plt.figure(figsize=(10, 6))
bars = plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'gold'])

# Подписи к столбцам
for bar, value in zip(bars, values):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(value, 2), ha='center', va='bottom', fontsize=12)

# Настройка графика
plt.ylabel('AUC-ROC', fontsize=14)
plt.title('Сравнение AUC-ROC для модели Опорные вектора (`SVC`)', fontsize=16)
plt.ylim(0, max(values) * 1.2)
plt.grid(axis='y', linestyle='--')

plt.show()


# Дополнительный график ROC-кривой (необязательно, но желательно для полной картины)
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, svc.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC кривая (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('ROC-кривая для модели Опорные вектора (`SVC`)', fontsize=16)
plt.legend(loc="lower right", fontsize=12)
plt.grid(axis='both', linestyle='--')
plt.show()

# %% [markdown]
# #### Вывод по использованию пейплайнов и выбору лучшей модели
# 1. Модель SVC (Support Vector Classification) показала наилучший результат среди всех моделей, достигнув среднего значения тестового балла 0.911237.
#
# 2. На втором месте модель KNeighborsClassifier (метод k-ближайших соседей), которая достигла среднего значения тестового балла 0.904624. Эта модель также продемонстрировала высокую точность, но немного уступила модели SVC.
#
# 3. Модель LogisticRegression с регуляризацией L1 заняла третье место со средним значением тестового балла 0.896662. Хотя она уступает первым двум моделям, её результат всё ещё достаточно высок.
#
# 4. Худшим результатом среди представленных моделей обладает DecisionTreeClassifier, который показал средний балл 0.807894. Эта модель значительно отстает от остальных по точности классификации.

# %% [markdown]
# ### Анализ важности признаков

# %% [markdown]
# #### Оценим значимость признаков на наилучшей модели дерева решений с помощью метода перестановочной важности. Визаулизируем какие признаки больше всего влияют на модель.

# %%
# Получаем лучшую модель дерева решений из GridSearchCV
best_model = dtc.best_estimator_.named_steps['models']

# Получаем предобработчик данных из GridSearchCV
preprocessor = dtc.best_estimator_.named_steps['preprocessor']

# Применяем предобработку к обучающим данным
X_train_preprocessed = preprocessor.transform(X_train)

# Применяем ту же предобработку к тестовым данным
X_test_preprocessed = preprocessor.transform(X_test)

# %%
# Список столбцов для one-hot encoding
ohe_columns = ['favorite_category'] 

# Список столбцов для ordinal encoding
ord_columns = ['service_type', 'adv_permision'] 

# Получение имен признаков после применения One-Hot Encoding
ohe_features = preprocessor.named_transformers_['ohe'].get_feature_names_out(ohe_columns)

# Получение имен признаков после применения Ordinal Encoding
ord_features = preprocessor.named_transformers_['ord'].get_feature_names_out(ord_columns)

# Сохранение списка числовых признаков без изменений
num_features = num_columns

# Объединение всех признаков (категориальных и числовых) в один общий список
all_features = list(ohe_features) + list(ord_features) + list(num_columns)

# %%
# Создание DataFrame из предобработанных данных обучающей выборки
X_train_df = pd.DataFrame(X_train_preprocessed)

# Создание DataFrame из предобработанных данных тестовой выборки
X_test_df = pd.DataFrame(X_test_preprocessed)

# Присвоение имен признаков из списка all_features столбцам DataFrame обучающей выборки
X_train_df.columns = all_features

# Присвоение имен признаков из списка all_features столбцам DataFrame тестовой выборки
X_test_df.columns = all_features

# Обучение наилучшей модели на предобработанных данных обучающей выборки и соответствующих метках
best_model.fit(X_train_preprocessed, y_train)
# Out:
# DecisionTreeClassifier(max_depth=289, max_features=19, random_state=42)

# %%
# Определение важности признаков с использованием метода permutation_importance
perm_importance = permutation_importance(
    best_model,  # Обученная модель, для которой вычисляется важность признаков
    X_test_preprocessed,  # Препроцессированные тестовые данные
    y_test,  # Целевые значения для тестового набора
    scoring='roc_auc',  # Используемая метрика для оценки важности (ROC-AUC)
    n_repeats=10,  # Количество повторов для стабильной оценки важности
    random_state=42  # Установка начального состояния для воспроизводимости
)

# Создание DataFrame с признаками и их важностью
importance_df = pd.DataFrame({
    'Feature': all_features,  # Названия отобранных признаков
    'Importance': perm_importance.importances_mean  # Среднее значение важности признаков
})

# Сортировка DataFrame по важности признаков в порядке убывания
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Отображение DataFrame с признаками и их важностью
importance_df
# Out:
#                                               Feature  Importance
# 10                         time_spent_on_site_min_m-1    0.123598
# 19                               pages_per_visits_3_m    0.082204
# 15                              %_promotion_purchases    0.058189
# 11                           time_spent_on_site_min_m    0.057429
# 7                                         revenue_m-2    0.045887
# 17                                   unpaid_purch_qtr    0.021016
# 9                                         revenue_m-1    0.016290
# 16                  avg_category_view_by_visit_last_m    0.008133
# 13                                 act_m_adv_activity    0.005422
# 14                                     life_time_days    0.004169
# 8                                           revenue_m    0.000720
# 3    favorite_category_Техника для красоты и здоровья    0.000592
# 0             favorite_category_Косметика и аксесуары    0.000498
# ...

# %% [markdown]
# #### Оценим важность признаков для лучшей модели и построим график важности с помощью метода SHAP

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', SVC(degree=3, probability=True, random_state=RANDOM_STATE))
]).fit(X_train, y_train)

best_model = svc.best_estimator_

X_train_trans = pd.DataFrame(data_preprocessor.transform(X_train), columns=data_preprocessor.get_feature_names_out())
X_test_trans = pd.DataFrame(data_preprocessor.transform(X_test), columns=data_preprocessor.get_feature_names_out())
explainer = shap.KernelExplainer(best_model.named_steps['models'].predict, X_train_trans)
shap_values = explainer.shap_values(X_test_trans, nsamples=100)
# Out:
# Using 975 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/325 [00:00<?, ?it/s]

# %%
# Инициализация JavaScript для интерактивных графиков SHAP (если нужно)
shap.initjs()

# Создание графика SHAP summary_plot
short_names = [name[:20] + '...' if len(name) > 20 else name for name in all_features]
shap.summary_plot(
    shap_values, 
    X_test_trans, 
    feature_names=short_names,
    plot_type="dot",
    show=False  # Убираем автоматическое отображение
)

# Получаем текущую фигуру и оси после создания summary_plot
fig = plt.gcf()
ax = plt.gca()

# Устанавливаем размер шрифта меток на осях
ax.tick_params(labelsize=14)

# Устанавливаем подпись оси X.
ax.set_xlabel("SHAP уровень влияния на выходные признаки", fontsize=14)

# Устанавливаем заголовок графика.
ax.set_title('Важность признаков лучшей модели', fontsize=14)

# Очистим фигуру от нежелательных элементов и настроим colorbar
for obj in fig.get_axes():
    if len(obj.collections) > 0:  # Проверяем, содержит ли какой-либо элемент
        cb = fig.colorbar(obj.collections[0], ax=ax)
        cb.ax.tick_params(labelsize=14)
        break

# Показываем график
plt.show()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Создание графика SHAP summary_plot
shap.summary_plot(shap_values, X_test_trans, plot_type='bar', show=False)

# Получаем текущую фигуру и ось после создания графика
fig = plt.gcf()
ax = plt.gca()

# Изменяем параметры графика
ax.tick_params(labelsize=14)
ax.set_xlabel("SHAP уровень влияния на выходные признаки", fontsize=14)
ax.set_title('Важность признаков лучшей модели', fontsize=16)

# Проверка наличия цветной шкалы
if len(fig.axes) > 1:
    cb_ax = fig.axes[1]
    
    # Изменяем параметры цветовой панели
    cb_ax.tick_params(labelsize=15)
    cb_ax.set_ylabel("Уровень важности признаков", fontsize=20)
else:
    print("Цветовая шкала отсутствует.")

plt.show()
# Out:
# Цветовая шкала отсутствует.

# %% [markdown]
# Наиболее значимые признаки метода SHAP совпадают со значимыми признаками для дерева решений

# %% [markdown]
# #### Выводы о значимости признаков:
#
# **Признаки мало значимы для модели**:
# * `favorite_category_Товары для детей` - популярная категория товаров у покупателя за последние 6 месяцев
# * `favorite_category_Кухонная посуда` - популярная категория товаров у покупателя за последние 6 месяцев
# * `favorite_category_Техника для красоты и здоровья` - популярная категория товаров у покупателя за последние 6 месяцев
# * `service_type` - уровень сервиса
# * `adv_permision` - Согласие на рассылки покупателю дополнительных предложений о товаре.
# * `act_m_adv_activity` - количество маркетинговых коммуникаций в текущем месяце.
# * `favorite_category_Мелкая бытовая техника и электроника` - популярная категория товаров у покупателя за последние 6 месяцев
#
# **Признаки сильнее всего влияют на целевой признак**:
# * `pages_per_visits_3_m` -  среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца
# * `time_spent_on_site_min_m-1` - среднее количество страниц, которые просмотрел покупатель за один визит на сайт за прошлый месяц
# * `time_spent_on_site_min_m` - среднее количество страниц, которые просмотрел покупатель за один визит на сайт за текущий месяц
# * `%_promotion_purchases` - среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# * `avg_category_view_by_visit_last_m` - сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# * `6_m_adv_activity` - среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев
# * `unpaid_purch_qtr` - общее число неоплаченных товаров в корзине за последние 3 месяца
# * `revenue_m-2` - сумма выручки за позапрошлый месяц
#
# Чем больше страниц пользователь просматривает за визит и чем больше времени проводит на сайте, тем выше его активность. Такие пользователи обычно относятся к категории стабильных, активно вовлеченных клиентов, чья активность остается на высоком уровне.
#
# Однако использование акционных предложений для повышения активности пользователей вызывает сомнения. Чем выше доля покупок, сделанных по акциям, тем больше вероятность, что этих покупателей классифицируют как клиентов с уменьшающейся активностью. Это может происходить из-за того, что акции привлекают временно заинтересованных клиентов, ищущих быструю выгоду, а не формируют лояльную клиентскую базу.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что используешь `SHAP` для анализа важности признаков.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай подписывать ось Y и название на графике. Так как `SHAP` график тоже является визуальным объектом, для его кастомизации мы можем использовать методы plt, как и для других графиков, однако это потребует небольшой настройки самого объекта `SHAP`. Подробнее можно глянуть тут: https://github.com/shap/shap/issues/594.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Спасибо за рекомендацию и ссылку. Дополнил*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ###  Сегментация покупателей

# %% [markdown]
# #### Выполним сегментацию покупателей. Используем результаты моделирования и данные о прибыльности покупателей.

# %%
X.head()
# Out:
#              revenue_m-2  revenue_m  revenue_m-1  time_spent_on_site_min_m-1  \
# customer_id
# 215348               0.0     3293.1          0.0                          13
# 215349            4472.0     4971.6       5216.0                          12
# 215350            4826.0     5058.4       5457.5                           8
# 215351            4793.0     6610.4       6158.0                          11
# 215352            4594.0     5872.5       5807.5                           8
#
#              time_spent_on_site_min_m service_type adv_permision  \
# customer_id
# 215348                             14      премиум            да
# 215349                             10      премиум            да
# 215350                             13     стандарт           нет
# 215351                             13     стандарт            да
# 215352                             11     стандарт           нет
#
#              6_m_adv_activity  act_m_adv_activity  life_time_days  \
# customer_id
# ...

# %%
customer_profit.head()
# Out:
#    customer_id  customer_profit
# 0       215348             0.98
# 1       215349             4.16
# 2       215350             3.13
# 3       215351             4.87
# 4       215352             4.21

# %%
def check_multiple_dfs(*dfs):
    """
    Проверяет основные свойства и признаки нескольких DataFrame.

    Параметры:
    dfs: Переменное количество аргументов, каждый из которых является pd.DataFrame.
    """
    for i, df in enumerate(dfs, start=1):
        print(f"\n=== DataFrame {i} ===")

        # Исключаем столбец 'customer_id' и создаем копию
        if 'customer_id' in df.columns:
            df = df.drop(columns=['customer_id']).copy()
        
        # Основные статистики
        print("\nОсновные статистики экземпляров DataFrame:")
        display(df.describe())

        # Элементарный визуальный анализ
        print("\nРаспределение первых нескольких числовых признаков:")
        numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns[:5]
        for column in numeric_columns:
            # Построение гистограммы
            plt.figure(figsize=(14, 6))
            plt.subplot(1, 2, 1)
            sns.histplot(df[column], kde=True)
            plt.title(f"Гистограмма: {column}")
            
            # Построение ящика с усами
            plt.subplot(1, 2, 2)
            sns.boxplot(x=df[column])
            plt.title(f"Ящик с усами: {column}")
            
            # Показ графиков
            plt.tight_layout()
            plt.show()

# Использование функции, customer_profit, X это переменные содержащие DataFrame
check_multiple_dfs(customer_profit, X)
# Out:
# === DataFrame 1 ===
#
# Основные статистики экземпляров DataFrame:
#        customer_profit
# count      1300.000000
# mean          3.996631
# std           1.013722
# min           0.860000
# 25%           3.300000
# 50%           4.045000
# 75%           4.670000
# max           7.430000
# Распределение первых нескольких числовых признаков:
# === DataFrame 2 ===
#
# Основные статистики экземпляров DataFrame:
#        revenue_m-2      revenue_m  revenue_m-1  time_spent_on_site_min_m-1  \
# count  1300.000000    1300.000000  1300.000000                 1300.000000
# mean   4825.206923    5314.960846  4936.920385                   13.467692
# std     405.979663    2939.708156   739.597997                    3.932029
# min       0.000000    2758.700000     0.000000                    5.000000
# 25%    4583.000000    4706.050000  4496.750000                   11.000000
# 50%    4809.000000    5179.950000  5005.000000                   13.000000
# ...

# %% [markdown]
# Анализ гистограммы распределения прибыли показывает, что у данных нормальное распределение, в котором большинство значений сконцентрировано около среднего.
#
# Для нормального распределениея известен факт, что примерно 68,26% всех значений находятся в пределах одного стандартного отклонения от среднего значения. Это может служить ориентиром при оценке уровня дохода: значения в этом диапазоне можно считать "обычными", тогда как те, что ниже или выше, можно отнести к низким или высоким доходам соответственно.
#
# Квантили в нормальном распределении представляют собой определенные процентные точки. Медиана соответствует 0,5-квантилю, что делит данные пополам. Верхний (0,75) и нижний (0,25) квартили указывают на границы верхней и нижней четверти данных.
#
# Таким образом, используя квантили, можно условно разграничить данные на группы, отражающие низкий, средний и высокий доход.

# %%
# Вычисление медианного значения колонки 'customer_profit' в DataFrame customer_profit
med = customer_profit['customer_profit'].median()

# Вычисление стандартного отклонения колонки 'customer_profit' с использованием библиотеки numpy
sd = np.std(customer_profit['customer_profit'])

# Вывод на экран медианного значения
print("Медианное значение : ", med)

# Вывод на экран стандартного отклонения
print("Стандартное отклонение : ", sd)

# Вывод описательной статистики для колонки 'customer_profit' в DataFrame customer_profit
customer_profit['customer_profit'].describe()
# Out:
# Медианное значение :  4.045
# Стандартное отклонение :  1.0133321434255445
# count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: customer_profit, dtype: float64

# %%
customer_profit.head()
# Out:
#    customer_id  customer_profit
# 0       215348             0.98
# 1       215349             4.16
# 2       215350             3.13
# 3       215351             4.87
# 4       215352             4.21

# %%
# Функция custom_predict предназначена для расчета предсказаний с использованием изменяемого порога вероятности
def custom_predict(X, threshold):
    # Вычисление вероятностей каждой из классов для объектов выборки X
    probs = pipe_final.predict_proba(X)
    # Возврат бинарных предсказаний: 1, если вероятность класса 1 больше заданного порога, иначе 0
    return (probs[:, 1] > threshold).astype(int)

# %%
# Получение предсказаний на основе данных X с использованием выбранного порога вероятности
# Функция custom_predict возвращает бинарные предсказания в зависимости от заданного порога
predictions_precision = custom_predict(X, threshold=0.5)

# Добавление в DataFrame X нового столбца 'predictions', содержащего значения предсказаний
# Эти предсказания представляют, к какому классу (например, 0 или 1) отнести каждый объект из X
X['predictions'] = predictions_precision

# Добавление в DataFrame X нового столбца 'probs', содержащего вероятности принадлежности к положительному классу
# Значения 'probs' определяют вероятность того, что объект принадлежит к положительному классу (например, 1)
X['probs'] = pipe_final.predict_proba(X)[:, 1]

# %%
X = pd.merge(X, customer_profit, on='customer_id', sort=True)

# %%
X.head()
# Out:
#    customer_id  revenue_m-2  revenue_m  revenue_m-1  \
# 0       215348          0.0     3293.1          0.0
# 1       215349       4472.0     4971.6       5216.0
# 2       215350       4826.0     5058.4       5457.5
# 3       215351       4793.0     6610.4       6158.0
# 4       215352       4594.0     5872.5       5807.5
#
#    time_spent_on_site_min_m-1  time_spent_on_site_min_m service_type  \
# 0                          13                        14      премиум
# 1                          12                        10      премиум
# 2                           8                        13     стандарт
# 3                          11                        13     стандарт
# 4                           8                        11     стандарт
#
#   adv_permision  6_m_adv_activity  act_m_adv_activity  life_time_days  \
# 0            да               3.4                   5             121
# 1            да               4.4                   4             819
# ...

# %% [markdown]
# Построим диаграмму рассеяния вероятности "Снижения покупательской активности" и прибыли для визуализации границы разделения на группы покупательской активности

# %%
# Устанавливаем размер фигуры для графика
plt.figure(figsize=[15, 5]) 
# Создаем диаграмму рассеяния с данными из столбцов 'probs' и 'customer_profit' DataFrame X
plt.scatter(X.probs, X.customer_profit) 
# Устанавливаем заголовок графика
plt.title('Диаграмма рассеяния "Покупательской активности и прибыли') 
# Подписываем ось X
plt.xlabel('Вероятность снижения активности клиента') 
# Подписывает ось Y
plt.ylabel('customer_profit, %') 
# Отображает график
plt.show()

# %% [markdown]
# Можно наблюдать, что при различных вероятностях снижения активности прибыль находится в основном в диапазоне от 1% до 7%.
# Также видим, что при значениях вероятности от 0,4 до 0,8 диапазон прибыльности сжимается и становится от 3 до 5,5 процентов.
# Также видно, что при основная часть клиентов сконцентрирована вокруг низкой и высокой вероятности снижения активности.
# Посмотрим свормируется ли по уровню активности отдельные сегменты, естественным образом с помощью метода KNN.

# %% [markdown]
# #### Сделамем сегментацию и сформируем предложения по работе с сегментами на основе их характеристик.

# %% [markdown]
# Сделаем сегментацию с помощью KNN

# %%
X.head()
# Out:
#    customer_id  revenue_m-2  revenue_m  revenue_m-1  \
# 0       215348          0.0     3293.1          0.0
# 1       215349       4472.0     4971.6       5216.0
# 2       215350       4826.0     5058.4       5457.5
# 3       215351       4793.0     6610.4       6158.0
# 4       215352       4594.0     5872.5       5807.5
#
#    time_spent_on_site_min_m-1  time_spent_on_site_min_m service_type  \
# 0                          13                        14      премиум
# 1                          12                        10      премиум
# 2                           8                        13     стандарт
# 3                          11                        13     стандарт
# 4                           8                        11     стандарт
#
#   adv_permision  6_m_adv_activity  act_m_adv_activity  life_time_days  \
# 0            да               3.4                   5             121
# 1            да               4.4                   4             819
# ...

# %%
# Определяем числовые признаки для нормализации
numeric_features = [
    'pages_per_visits_3_m',
    'time_spent_on_site_min_m',
    'time_spent_on_site_min_m-1',
    '%_promotion_purchases',
    'avg_category_view_by_visit_last_m',
    '6_m_adv_activity',
    'unpaid_purch_qtr',
    'revenue_m-2',
    'customer_profit',
    'probs'
]


# Нормализация данных
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[numeric_features])

#Определение оптимального числа кластеров
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# Построение графика метода "локтя"
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Метод локтя')
plt.xlabel('Количество кластеров')
plt.ylabel('WCSS')
plt.show()

# 3. Применение KMeans с выбранным количеством кластеров
kmeans = KMeans(n_clusters=3, random_state=42)
X['cluster'] = kmeans.fit_predict(X_scaled)

# 4. Визуализация кластеров на плоскости PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

# Добавляем результаты PCA в DataFrame для визуализации
X['PCA1'] = pca_result[:, 0]
X['PCA2'] = pca_result[:, 1]

plt.figure(figsize=(10, 7))
plt.scatter(X['PCA1'], X['PCA2'], c=X['cluster'], cmap='viridis')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Кластеризация KMeans с использованием PCA')
plt.colorbar(label='Кластер')
plt.show()

# %% [markdown]
# На графике "локоть" можно увидеть в районе 2-3 кластеров. Это значит, что можно выбрать 2 или 3 кластера для дальнейшего анализа.

# %%
# Добавим столбец 'segment' в DataFrame X с метками кластеров, предсказанными моделью k-means.
X['segment'] = kmeans.labels_

# %%
X.head()
# Out:
#    customer_id  revenue_m-2  revenue_m  revenue_m-1  \
# 0       215348          0.0     3293.1          0.0
# 1       215349       4472.0     4971.6       5216.0
# 2       215350       4826.0     5058.4       5457.5
# 3       215351       4793.0     6610.4       6158.0
# 4       215352       4594.0     5872.5       5807.5
#
#    time_spent_on_site_min_m-1  time_spent_on_site_min_m service_type  \
# 0                          13                        14      премиум
# 1                          12                        10      премиум
# 2                           8                        13     стандарт
# 3                          11                        13     стандарт
# 4                           8                        11     стандарт
#
#   adv_permision  6_m_adv_activity  act_m_adv_activity  ...  unpaid_purch_qtr  \
# 0            да               3.4                   5  ...                 2
# 1            да               4.4                   4  ...                 4
# ...

# %%
# Группируем данные по столбцу 'segment'
segment_summary = X.groupby('segment').mean()

# Выводим сводную таблицу средних значений для каждого сегмента
display(segment_summary)
# Out:
#            customer_id  revenue_m-2    revenue_m  revenue_m-1  \
# segment
# 0        216177.982571  4869.653595  5238.242048  4904.753813
# 1        216184.461187  5010.778539  5156.855479  4965.835616
# 2        215588.739454  4572.895782  5574.176923  4942.130273
#
#          time_spent_on_site_min_m-1  time_spent_on_site_min_m  \
# segment
# 0                         14.555556                 13.474946
# 1                         15.673516                 15.876712
# 2                          9.831266                  9.992556
#
#          6_m_adv_activity  act_m_adv_activity  life_time_days  \
# segment
# 0                4.618519            4.058824      563.612200
# 1                4.532420            3.947489      617.632420
# 2                3.535484            4.027295      628.404467
#
#          %_promotion_purchases  avg_category_view_by_visit_last_m  \
# segment
# 0                     0.241002                           4.067538
# ...

# %% [markdown]
# #### Опишем получившиеся сегменты на основе средних значений для каждого из них:
#
# **Сегмент 0**
# - Вероятность снижения активности (`probs`): Низкая, около 0.107, означает, что эти клиенты, скорее всего, сохранят текущую активность.
# - Средний доход: Умеренно высокий, около 4869 - 5238
# - Прибыль: Высокая, около 3.36
# - Время на сайте: Чуть выше среднего, 13.47 минут в предыдущем месяце и 14,55 минут в текущем
# - Рекламная активность: Среднее значение, около 3.94 в 6 месяцев и 4.05 в текущем месяце
# - Время с момента регистриации: умеренно высокое, около 563 дней
# - Процент покупок по акции: Низкий, 0.24
# - Проблемы с сайтом: Часто, в среднем 4.19 аварий
# - Неоплаченные товары в корзине: Низкое, 2.44
# - Страниц на посещение: Достаточно высокое, 10.63 страниц
#
# **Сегмент 1**
# - Вероятность снижения активности (`probs`): Низкая, около 0.132, что указывает на устойчивую активность клиентов в будущем.
# - Средний доход: Похож на сегмент 0, но с меньшей вариативностью, около 4966 - 5156
# - Прибыль: Умеренная, около 4.65, самая высокая среди сегментов. Это основное отличие от сегмента 0
# - Время на сайте: Меньше, чем у первого сегмента, но близко к среднему, 15.88 минут в предыдущем месяце, 15.67 в текущем
# - Рекламная активность: Чуть выше, 4.53 за 6 месяцев, 3.94 в текущем
# - Время с момента регистриации: Умеренное, около 617 дней
# - Процент покупок по акции: Низкий, 0.236
# - Проблемы с сайтом: Часто, в среднем 4.48 аварий
# - Неоплаченные товары в корзине: Низкое, 2.16.
# - Страниц на посещение: Высокое, 9.10 страниц
#
# **Сегмент 2**
# - Вероятность снижения активности (`probs`): Высокая, около 0.93, что указывает на риск значительного снижения активности, требующего разработки стратегий по удержанию.
# - Средний доход: Более изменчивый, 4572 - 5574
# - Прибыль: Высокая, около 4.00
# - Время на сайте: Ниже среднего, 9.83 минут в предыдущем месяце, 9.99 в текущем. Меньшее среди всех сегментов время на сайте.
# - Рекламная активность: Ниже остальных, 4.53 за 6 месяцев, 3.94 в текущем
# - Время с момента регистрации: Выше, около 630 дней
# - Процент покупок по акции: Высокий, 0.50 - самый высокий среди сегментов
# - Проблемы с сайтом: Реже, в среднем 3.85 аварий
# - Неоплаченные товары в корзине (`unpaid_purch_qtr`): Выше, 4.022. самое большое количество среди сегментов
# - Страниц на посещение: Заметно ниже, 4.36. Самое маленькое среди сегментов
#
#
# **Рекомендации по предложениям и работе с сегментами:**
#
#
# **Сегмент 0**
# -Сегмент 0 имеет схожий с сегментом 1 доход, немного отличается по разбросу уровня дохода и времени пребывания на сайте и заметно отличается по уровню прибыли в этом сегменте ниже, что может говорить о потенциале необходимости кросс-продаж более прибыльных товаров.
#
# - Рекомендации:
# Поддержание вовлеченности, с акцентом на кросс-продажи прибыльных товаров.
# Разработать рекламную компанию с продвижением более прибыльных товаров, характерных для этой аудитории. Провести анализ схожести поведения клиентов с сегментом 0 и при идентификации схожих паттернов поведения предложить аналогичные, товары.
#
# **Сегмент 1:**
# - Сегмент 1 можно охарактеризовать как клиентов с стабильным поведением и высокой активностью на сайте, склонные к высоким доходам и хорошей прибыли.
# Рекоментации:
# - Поддежание вовлеченности как и сегмента 1 + продолжать поддерживать высокий уровень удовлетворенности клиентов через программы лояльности и персонализированные предложения.
#
# **Сегмент 2:**
#  Сегмент 2 выделяется высокой вероятностью снижения активности. При этом это довольно ценный для магазина сегмент с высокой прибылью. У этого сегмента самый высокий % покупок по акциям и самое большое количество товаров в корзине без оплаты. В работе с этим сегментов нужно сфокусироваться на поддержании их активности, эти клиенты любят акции, кажется что ждут их откладывая товары в корзине.
#
# - Рекомендации:
# Проводить целевые акции по удержанию и предоставлять дополнительные стимулы для совершения покупок. Разработать акцию с персональными предложениями на товары оставленные в корзине. Увеличить уровень целевых рекламных активностей. Чаше проводить для этого сегмента распродажи.
#
#
# **Общие рекомендации для всех сегментов:**
# - Анализ причин неоплаченных товаров: Нужно постараться выяснить, почему клиенты оставляют товары в корзине (например, высокие цены, сложность процесса покупки или технические сбои).
# - Устойчивость сайта: Устраняйте регулярные технические проблемы для улучшения киентского опыта.
# - Улучшение сайта и уровня поддержки: Поскольку клиенты сталкиваются с частыми авариями, проведите технический аудит и оптимизацию для снижения количества сбоев. Также нужно сделать простой альтернативный канал для взаимодействия с клиентами, во время технической проблемы, например переход в приложение или обратный звонок.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Классный подход к сегментации с использованием кластеризации.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# **Задача:**
# - Интернет-магазин «В один клик» столкнулся со снижением активности покупателей. Поставлена задача разработать решение для персонализации предложений постоянным клиентам с целью увеличения их покупательской активности. Необходимо построить модель, предсказывающую вероятность снижения активности клиента в следующие три месяца, и на ее основе выделить сегменты покупателей для разработки персонализированных предложений.
#
# **Исходные данные и предобработка:**
# - Использовались таблицы с данными о поведении покупателей, их активности на сайте, выручке и прибыли. В ходе предобработки были выявлены и исправлены опечатки, проверены и приведены к нужным типам данных, отобраны только активные покупатели за последние 3 месяца. Проведена трансформация данных из "длинного" в "широкий" формат для анализа.
#
# **Поиск лучшей модели:**
# - Для поиска лучшей модели использовались пайплайны с различными комбинациями преобраpователей данных и моделей классификации. Проведено обучение и сравнение четырех моделей: K-ближайших соседей, Дерево решений, Логистическая регрессия и SVC. Лучшая модель выбрана по метрике ROC-AUC на кросс-валидации.
#
# **Лучшая модель:**
# - Наилучший результат показала модель SVC со средним значением ROC-AUC 0.911 на кросс-валидации.
#
# **Выводы и дополнительные предложения по сегментам:**
#
# По результатам моделирования и анализа прибыльности клиенты были разделены на 3 сегмента.
#
# Сегмент 0 - клиенты с стабильно высокой активностью и прибылью. Рекомендуется поддерживать их лояльность через программы лояльности и персонализированные предложения.
#
# Сегмент 1 - клиенты со средней прибылью и потенциалом ее увеличения. Предлагается фокус на кросс-продажи более прибыльных товаров через целевые рекламные кампании.
#
# Сегмент 2 - клиенты с высоким риском снижения активности, но приносящие хорошую прибыль. Рекомендуются акции по удержанию, персональные предложения на товары в корзине, увеличение частоты распродаж.
#
# Дополнительно для всех сегментов рекомендуется проанализировать причины возникновения неоплаченных заказов, устранить частые технические проблемы сайта и разработать альтернативные каналы взаимодействия с клиентами на случай сбоев.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Александр, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `RandomizedSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Алексей,*
#
# *Большое спасибо за ревью, полезные рекомендации и ссылки. Здорово, что вместе с замечанием даешь сслыку, по которой можно посмотреть и разобраться, как исправить. Особенно признателен за оперативность в ревью, т.к. немного переживаю, что не успею сделать финальный проект. Проект доработан, направлюя на повторное рассмотрение.*
#
# *С уважением, Александр*
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: итоговый вывод по проекту.
#
# Александр, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
